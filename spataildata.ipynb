# %%
# !pip install folium

# %%
import folium
mymap = folium.Map(location = [12.971599,77.594566],
                   width = 950,
                   height = 550,
                   zoom_start = 12,
                   titles = 'opendtreetmap')
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_17b014a91dae9269368be517cb02caab {
#                     position: relative;
#                     width: 950.0px;
#                     height: 550.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_17b014a91dae9269368be517cb02caab&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_17b014a91dae9269368be517cb02caab = L.map(
#                 &quot;map_17b014a91dae9269368be517cb02caab&quot;,
#                 {
#                     center: [12.971599, 77.594566],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     titles: &quot;opendtreetmap&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c9fd6db7d0a538ba864877f994d42c66 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_17b014a91dae9269368be517cb02caab);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium
mymap = folium.Map(location=[21.0404, 82.4509], zoom_start=5)

locations = {
    "Presidency university": (13.1018, 77.3210),
    "ISKCON temple": (13.0035, 77.3303),
    "Laalbagh lake": (12.5645, 77.3459),
    "PARLE BISCUITS FACTORY": (13.0256, 77.2936),
    "DL Track Peenya": (13.0212, 77.3141)
}

for location, coordinates in locations.items():
    folium.Marker(location=coordinates, popup=location).add_to(mymap)

mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_31c1ee954df0d9d3feddf4b7a6951548 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_31c1ee954df0d9d3feddf4b7a6951548&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_31c1ee954df0d9d3feddf4b7a6951548 = L.map(
#                 &quot;map_31c1ee954df0d9d3feddf4b7a6951548&quot;,
#                 {
#                     center: [21.0404, 82.4509],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_08705b7d190b3326baa09c2e074ce57d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_31c1ee954df0d9d3feddf4b7a6951548);
#
#
#             var marker_06cd56542a39c81e2b7371e4efa68157 = L.marker(
#                 [13.1018, 77.321],
#                 {}
#             ).addTo(map_31c1ee954df0d9d3feddf4b7a6951548);
#
#
#         var popup_d51b560e3a8b3b9aba615e80aca4c5bb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_682bcca285857490906af62a60ce4a26 = $(`&lt;div id=&quot;html_682bcca285857490906af62a60ce4a26&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Presidency university&lt;/div&gt;`)[0];
#                 popup_d51b560e3a8b3b9aba615e80aca4c5bb.setContent(html_682bcca285857490906af62a60ce4a26);
#
#
#
#         marker_06cd56542a39c81e2b7371e4efa68157.bindPopup(popup_d51b560e3a8b3b9aba615e80aca4c5bb)
#         ;
#
#
#
#
#             var marker_8672f4e209da13e576086696f279b149 = L.marker(
#                 [13.0035, 77.3303],
#                 {}
#             ).addTo(map_31c1ee954df0d9d3feddf4b7a6951548);
#
#
#         var popup_a216c86046996d5a49fa30a888c640d4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0dd54aec339dee018e698d611211cbf2 = $(`&lt;div id=&quot;html_0dd54aec339dee018e698d611211cbf2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ISKCON temple&lt;/div&gt;`)[0];
#                 popup_a216c86046996d5a49fa30a888c640d4.setContent(html_0dd54aec339dee018e698d611211cbf2);
#
#
#
#         marker_8672f4e209da13e576086696f279b149.bindPopup(popup_a216c86046996d5a49fa30a888c640d4)
#         ;
#
#
#
#
#             var marker_f88a6dfd05996828ea0ab8e99d496d52 = L.marker(
#                 [12.5645, 77.3459],
#                 {}
#             ).addTo(map_31c1ee954df0d9d3feddf4b7a6951548);
#
#
#         var popup_abf44965729552c0c33cb4fce2502766 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_733798598e4c7c7c2b36e3d0b2b77deb = $(`&lt;div id=&quot;html_733798598e4c7c7c2b36e3d0b2b77deb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Laalbagh lake&lt;/div&gt;`)[0];
#                 popup_abf44965729552c0c33cb4fce2502766.setContent(html_733798598e4c7c7c2b36e3d0b2b77deb);
#
#
#
#         marker_f88a6dfd05996828ea0ab8e99d496d52.bindPopup(popup_abf44965729552c0c33cb4fce2502766)
#         ;
#
#
#
#
#             var marker_c53aab5bc9c3316ddf9b4dbf5149639c = L.marker(
#                 [13.0256, 77.2936],
#                 {}
#             ).addTo(map_31c1ee954df0d9d3feddf4b7a6951548);
#
#
#         var popup_45b1dde35386d517cca3c57d236b9f30 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e296611a6e5e5eb99fd250929c393256 = $(`&lt;div id=&quot;html_e296611a6e5e5eb99fd250929c393256&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;PARLE BISCUITS FACTORY&lt;/div&gt;`)[0];
#                 popup_45b1dde35386d517cca3c57d236b9f30.setContent(html_e296611a6e5e5eb99fd250929c393256);
#
#
#
#         marker_c53aab5bc9c3316ddf9b4dbf5149639c.bindPopup(popup_45b1dde35386d517cca3c57d236b9f30)
#         ;
#
#
#
#
#             var marker_64ef68c33fd121fceb5ff14f38ba13fb = L.marker(
#                 [13.0212, 77.3141],
#                 {}
#             ).addTo(map_31c1ee954df0d9d3feddf4b7a6951548);
#
#
#         var popup_804c72a4ca4acf6d2c67c148fde8af45 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_325d04072052cf69db0a2ae10d7ff9b8 = $(`&lt;div id=&quot;html_325d04072052cf69db0a2ae10d7ff9b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;DL Track Peenya&lt;/div&gt;`)[0];
#                 popup_804c72a4ca4acf6d2c67c148fde8af45.setContent(html_325d04072052cf69db0a2ae10d7ff9b8);
#
#
#
#         marker_64ef68c33fd121fceb5ff14f38ba13fb.bindPopup(popup_804c72a4ca4acf6d2c67c148fde8af45)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen web

# %%
import folium
#BANGLORE MAP WITH FAMOUS PLACES INCLUDING IMAGES
# Latitude and longitude coordinates of Bangalore
bangalore_coords = (12.9716, 77.5946)

# Create a map centered around Bangalore
map_bangalore = folium.Map(location=bangalore_coords, zoom_start=12)

# Define famous places and their coordinates in Bangalore

places = {
    "Lalbagh Botanical Garden": (12.9507, 77.5844),
    "Cubbon Park": (12.9757, 77.5929),
    "Bangalore Palace": (12.97194, 77.5936),
    "Vidhana Soudha": (12.979693, 77.590658),
    "Presidency University": (13.1682, 77.5354),
    "Wonderla": (12.834300, 77.414558)   ,
    "M Chinnaswamy Stadium": (12.9784, 77.5994),
    "Isckon temple": (13.00981, 77.55109),
    "Kempegowda International Airport": (13.192665896, 77.70333052)
}



# Define images for each place
images = {
    "Lalbagh Botanical Garden": "https://dynamic-media-cdn.tripadvisor.com/media/photo-o/0c/7d/47/f4/lalbagh-botanical-garden.jpg?w=1200&h=1200&s=1",
    "Cubbon Park": "https://tse1.mm.bing.net/th?id=OIP.G-kjAcQb59k6I1vQ_XcHEwHaE8&pid=Api&P=0&h=180",
    "Bangalore Palace": "https://tse2.mm.bing.net/th?id=OIP.i8dzBHIHgsZ0D9JK9tzSMwHaEo&pid=Api&P=0&h=180",
    "Vidhana Soudha": "https://tse3.mm.bing.net/th?id=OIP.LMgE0-vo4Fk26srdnaMdYgHaFj&pid=Api&P=0&h=180",
    "Presidency University": "https://tse1.mm.bing.net/th?id=OIP.X_YkcFxJv_Hy_fDFMfJv-gHaE8&pid=Api&P=0&h=180",
    "Wonderla": "https://tse2.mm.bing.net/th?id=OIP.p-jWkEz-iJvmLc4PtPFwAAHaE8&pid=Api&P=0&h=180",
    "M Chinnaswamy Stadium": "https://tse1.mm.bing.net/th?id=OIP.NepFTWdG0NbPcLL2XFI-jQHaEK&pid=Api&P=0&h=180",
    "Isckon temple": "https://tse1.mm.bing.net/th?id=OIP.76ttZ61WrTg-a-nuYSpdPAHaFj&pid=Api&P=0&h=180",
    "Kempegowda International Airport": "https://tse4.mm.bing.net/th?id=OIP.tu4IQk62ZmQfQhbIPDfZ8AHaE8&pid=Api&P=0&h=180"
}

# Add markers for each place
for place, coords in places.items():
    popup_content = f'<b>{place}</b><br><img src="{images[place]}" width="200">'
    folium.Marker(location=coords, popup=folium.Popup(popup_content, max_width=300)).add_to(map_bangalore)

# Display the map
map_bangalore
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5f2fe6c3b5f2207b5ecbb82c38dbd7e2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5f2fe6c3b5f2207b5ecbb82c38dbd7e2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5f2fe6c3b5f2207b5ecbb82c38dbd7e2 = L.map(
#                 &quot;map_5f2fe6c3b5f2207b5ecbb82c38dbd7e2&quot;,
#                 {
#                     center: [12.9716, 77.5946],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_74f00695a6a86bc442785b285243f1f3 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5f2fe6c3b5f2207b5ecbb82c38dbd7e2);
#
#
#             var marker_4976a6e8d5d02f351d1ca9e7d8b350c9 = L.marker(
#                 [12.9507, 77.5844],
#                 {}
#             ).addTo(map_5f2fe6c3b5f2207b5ecbb82c38dbd7e2);
#
#
#         var popup_42fb20c9aa35c4565a2dfef4aa3d95ba = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_bfa0829d031ff0c975d1b7ea526fba43 = $(`&lt;div id=&quot;html_bfa0829d031ff0c975d1b7ea526fba43&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Lalbagh Botanical Garden&lt;/b&gt;&lt;br&gt;&lt;img src=&quot;https://dynamic-media-cdn.tripadvisor.com/media/photo-o/0c/7d/47/f4/lalbagh-botanical-garden.jpg?w=1200&amp;h=1200&amp;s=1&quot; width=&quot;200&quot;&gt;&lt;/div&gt;`)[0];
#                 popup_42fb20c9aa35c4565a2dfef4aa3d95ba.setContent(html_bfa0829d031ff0c975d1b7ea526fba43);
#
#
#
#         marker_4976a6e8d5d02f351d1ca9e7d8b350c9.bindPopup(popup_42fb20c9aa35c4565a2dfef4aa3d95ba)
#         ;
#
#
#
#
#             var marker_1a2ce7b2f27e9e3921640d3b8a868606 = L.marker(
#                 [12.9757, 77.5929],
#                 {}
#             ).addTo(map_5f2fe6c3b5f2207b5ecbb82c38dbd7e2);
#
#
#         var popup_9e590f0ec26d610250ac525413f121fe = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_f3c08b08aa31b15726e33b6633d82303 = $(`&lt;div id=&quot;html_f3c08b08aa31b15726e33b6633d82303&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Cubbon Park&lt;/b&gt;&lt;br&gt;&lt;img src=&quot;https://tse1.mm.bing.net/th?id=OIP.G-kjAcQb59k6I1vQ_XcHEwHaE8&amp;pid=Api&amp;P=0&amp;h=180&quot; width=&quot;200&quot;&gt;&lt;/div&gt;`)[0];
#                 popup_9e590f0ec26d610250ac525413f121fe.setContent(html_f3c08b08aa31b15726e33b6633d82303);
#
#
#
#         marker_1a2ce7b2f27e9e3921640d3b8a868606.bindPopup(popup_9e590f0ec26d610250ac525413f121fe)
#         ;
#
#
#
#
#             var marker_250aa3ad82d726345899ffa1eb2157d5 = L.marker(
#                 [12.97194, 77.5936],
#                 {}
#             ).addTo(map_5f2fe6c3b5f2207b5ecbb82c38dbd7e2);
#
#
#         var popup_e134c92b4dc7dacd5b15aade44d0c69b = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_172c12a899fd585abad615562432c542 = $(`&lt;div id=&quot;html_172c12a899fd585abad615562432c542&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Bangalore Palace&lt;/b&gt;&lt;br&gt;&lt;img src=&quot;https://tse2.mm.bing.net/th?id=OIP.i8dzBHIHgsZ0D9JK9tzSMwHaEo&amp;pid=Api&amp;P=0&amp;h=180&quot; width=&quot;200&quot;&gt;&lt;/div&gt;`)[0];
#                 popup_e134c92b4dc7dacd5b15aade44d0c69b.setContent(html_172c12a899fd585abad615562432c542);
#
#
#
#         marker_250aa3ad82d726345899ffa1eb2157d5.bindPopup(popup_e134c92b4dc7dacd5b15aade44d0c69b)
#         ;
#
#
#
#
#             var marker_6f6e8b32ca4361df274011d8c4e62943 = L.marker(
#                 [12.979693, 77.590658],
#                 {}
#             ).addTo(map_5f2fe6c3b5f2207b5ecbb82c38dbd7e2);
#
#
#         var popup_865aad8efbbb9cc38793d9adba1b7d84 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_f162198de141560abfe5750cdc466509 = $(`&lt;div id=&quot;html_f162198de141560abfe5750cdc466509&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Vidhana Soudha&lt;/b&gt;&lt;br&gt;&lt;img src=&quot;https://tse3.mm.bing.net/th?id=OIP.LMgE0-vo4Fk26srdnaMdYgHaFj&amp;pid=Api&amp;P=0&amp;h=180&quot; width=&quot;200&quot;&gt;&lt;/div&gt;`)[0];
#                 popup_865aad8efbbb9cc38793d9adba1b7d84.setContent(html_f162198de141560abfe5750cdc466509);
#
#
#
#         marker_6f6e8b32ca4361df274011d8c4e62943.bindPopup(popup_865aad8efbbb9cc38793d9adba1b7d84)
#         ;
#
#
#
#
#             var marker_fa3f96fd4f33513f8228df299cd42d35 = L.marker(
#                 [13.1682, 77.5354],
#                 {}
#             ).addTo(map_5f2fe6c3b5f2207b5ecbb82c38dbd7e2);
#
#
#         var popup_1deaea06dac3f3c6b83cbe6eebdd4555 = L.popup({&
